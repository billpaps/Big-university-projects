# %%
import numpy as np
from keras.datasets import mnist
from keras import layers, optimizers
from keras import models
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
#Shows the acc and loss plots.
def show_plot(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(1,len(acc) + 1)

  plt.plot(epochs, acc, 'bo', label='Training acc')
  plt.plot(epochs, val_acc, 'b', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %%
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

# %%
print(train_data.shape)
print(test_data.shape)

#use this if we train cnn networks
# train_data = train_data.reshape((60000,28,28,1))
# test_data = test_data.reshape((10000,28,28,1))

#use this if we train mlp networks
train_data = train_data.reshape((60000, 28 * 28))
test_data = test_data.reshape((10000, 28 * 28))

train_data = train_data.astype('float32') / 255
test_data = test_data.astype('float32') / 255

# train_labels = to_categorical(train_labels)
# test_labels = to_categorical(test_labels)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'relu', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'relu', input_shape=(28*28,)))
network.add(layers.Dense(128, activation = 'relu'))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=30, 
                      batch_size=128,
                      validation_data=(test_data,test_labels))
# Out:
# Epoch 1/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2693 - accuracy: 0.9208 - val_loss: 0.1260 - val_accuracy: 0.9611
# Epoch 2/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1054 - accuracy: 0.9679 - val_loss: 0.0928 - val_accuracy: 0.9720
# Epoch 3/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0700 - accuracy: 0.9788 - val_loss: 0.0972 - val_accuracy: 0.9715
# Epoch 4/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0516 - accuracy: 0.9842 - val_loss: 0.0761 - val_accuracy: 0.9774
# Epoch 5/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0394 - accuracy: 0.9876 - val_loss: 0.0820 - val_accuracy: 0.9756
# Epoch 6/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.0706 - val_accuracy: 0.9793
# Epoch 7/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0239 - accuracy: 0.9924 - val_loss: 0.0800 - val_accuracy: 0.9789
# Epoch 8/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.0900 - val_accuracy: 0.9789
# Epoch 9/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0155 - accuracy: 0.9954 - val_loss: 0.0866 - val_accuracy: 0.9797
# Epoch 10/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0999 - val_accuracy: 0.9778
# Epoch 11/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0952 - val_accuracy: 0.9795
# Epoch 12/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.1035 - val_accuracy: 0.9799
# Epoch 13/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.1026 - val_accuracy: 0.9803
# Epoch 14/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.1056 - val_accuracy: 0.9801
# Epoch 15/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.1106 - val_accuracy: 0.9805
# Epoch 16/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.1358 - val_accuracy: 0.9784
# Epoch 17/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.1270 - val_accuracy: 0.9806
# Epoch 18/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.1490 - val_accuracy: 0.9779
# Epoch 19/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.1411 - val_accuracy: 0.9806
# Epoch 20/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.1365 - val_accuracy: 0.9809
# Epoch 21/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.1599 - val_accuracy: 0.9798
# Epoch 22/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1527 - val_accuracy: 0.9804
# Epoch 23/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.1547 - val_accuracy: 0.9809
# Epoch 24/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.1734 - val_accuracy: 0.9798
# Epoch 25/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.1615 - val_accuracy: 0.9807
# Epoch 26/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.1661 - val_accuracy: 0.9803
# Epoch 27/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.1558 - val_accuracy: 0.9813
# Epoch 28/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1763 - val_accuracy: 0.9804
# Epoch 29/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1721 - val_accuracy: 0.9810
# Epoch 30/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1589 - val_accuracy: 0.9816

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'relu', input_shape=(28*28,)))
network.add(layers.Dense(128, activation = 'relu'))
network.add(layers.Dense(128, activation = 'relu'))
network.add(layers.Dense(128, activation = 'relu'))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=10, 
                      batch_size=128,
                      validation_data=(test_data,test_labels))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2823 - accuracy: 0.9130 - val_loss: 0.1665 - val_accuracy: 0.9463
# Epoch 2/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1050 - accuracy: 0.9679 - val_loss: 0.1029 - val_accuracy: 0.9663
# Epoch 3/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0716 - accuracy: 0.9777 - val_loss: 0.1235 - val_accuracy: 0.9686
# Epoch 4/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0546 - accuracy: 0.9827 - val_loss: 0.1044 - val_accuracy: 0.9719
# Epoch 5/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0420 - accuracy: 0.9869 - val_loss: 0.0948 - val_accuracy: 0.9744
# Epoch 6/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.0789 - val_accuracy: 0.9792
# Epoch 7/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0291 - accuracy: 0.9909 - val_loss: 0.1049 - val_accuracy: 0.9763
# Epoch 8/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0236 - accuracy: 0.9927 - val_loss: 0.1197 - val_accuracy: 0.9759
# Epoch 9/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0963 - val_accuracy: 0.9807
# Epoch 10/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0181 - accuracy: 0.9943 - val_loss: 0.1030 - val_accuracy: 0.9802

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=30, 
                      batch_size=256,
                      verbose=0,
                      validation_data=(test_data,test_labels))

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(128, activation = 'sigmoid'))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=15, 
                      batch_size=128,
                      verbose=0,
                      validation_data=(test_data,test_labels))

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=15, 
                      batch_size=128,
                      verbose=0,
                      validation_data=(test_data,test_labels))

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))

optimizer = optimizers.RMSprop(learning_rate=0.0001)

network.compile(optimizer=optimizer,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=15, 
                      batch_size=128,
                      validation_data=(test_data,test_labels))

show_plot(history)
# Out:
# Epoch 1/15
# 469/469 [==============================] - 1s 3ms/step - loss: 1.3064 - accuracy: 0.7307 - val_loss: 0.7314 - val_accuracy: 0.8557
# Epoch 2/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.5852 - accuracy: 0.8688 - val_loss: 0.4636 - val_accuracy: 0.8917
# Epoch 3/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.4292 - accuracy: 0.8922 - val_loss: 0.3766 - val_accuracy: 0.9050
# Epoch 4/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3673 - accuracy: 0.9025 - val_loss: 0.3350 - val_accuracy: 0.9108
# Epoch 5/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3329 - accuracy: 0.9090 - val_loss: 0.3095 - val_accuracy: 0.9154
# Epoch 6/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3105 - accuracy: 0.9139 - val_loss: 0.2919 - val_accuracy: 0.9194
# Epoch 7/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2939 - accuracy: 0.9178 - val_loss: 0.2788 - val_accuracy: 0.9219
# Epoch 8/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2807 - accuracy: 0.9207 - val_loss: 0.2680 - val_accuracy: 0.9238
# Epoch 9/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2695 - accuracy: 0.9240 - val_loss: 0.2595 - val_accuracy: 0.9251
# Epoch 10/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2598 - accuracy: 0.9261 - val_loss: 0.2498 - val_accuracy: 0.9285
# Epoch 11/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2509 - accuracy: 0.9290 - val_loss: 0.2435 - val_accuracy: 0.9300
# Epoch 12/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2429 - accuracy: 0.9306 - val_loss: 0.2362 - val_accuracy: 0.9323
# Epoch 13/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2354 - accuracy: 0.9329 - val_loss: 0.2303 - val_accuracy: 0.9337
# Epoch 14/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2285 - accuracy: 0.9346 - val_loss: 0.2233 - val_accuracy: 0.9367
# Epoch 15/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2219 - accuracy: 0.9368 - val_loss: 0.2181 - val_accuracy: 0.9374

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))

#setting the optimizer
optimizer = optimizers.RMSprop(learning_rate=0.0001)

network.compile(optimizer=optimizer,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=40, 
                      batch_size=128,
                      verbose=0,
                      validation_data=(test_data,test_labels))

show_plot(history)

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))

optimizer = optimizers.RMSprop(learning_rate=0.0001)

network.compile(optimizer=optimizer,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=40, 
                      batch_size=128,
                      verbose=0,
                      validation_data=(test_data,test_labels))

show_plot(history)

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))

optimizer = optimizers.RMSprop(learning_rate=0.0001)

network.compile(optimizer=optimizer,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=100, 
                      batch_size=128,
                      verbose=0,
                      validation_data=(test_data,test_labels))

show_plot(history)

# %%
print(max(history.history['val_accuracy']))
print(min(history.history['val_loss']))
# Out:
# 0.9760000109672546
# 0.0798490047454834

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))

optimizer = optimizers.RMSprop(learning_rate=0.0001)

network.compile(optimizer=optimizer,
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=200, 
                      batch_size=128,
                      verbose=0,
                      validation_data=(test_data,test_labels))

show_plot(history)

# %%
print(max(history.history['val_accuracy']))
print(min(history.history['val_loss']))
# Out:
# 0.9804999828338623
# 0.06260814517736435

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_data, train_labels ,
                    epochs=30, 
                    batch_size=64,
                    validation_data=(test_data, test_labels))

show_plot(history)
# Out:
# Epoch 1/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1822 - accuracy: 0.9429 - val_loss: 0.0491 - val_accuracy: 0.9840
# Epoch 2/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0481 - accuracy: 0.9853 - val_loss: 0.0521 - val_accuracy: 0.9843
# Epoch 3/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0335 - accuracy: 0.9893 - val_loss: 0.0300 - val_accuracy: 0.9907
# Epoch 4/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 0.0339 - val_accuracy: 0.9897
# Epoch 5/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0204 - accuracy: 0.9939 - val_loss: 0.0251 - val_accuracy: 0.9914
# Epoch 6/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 0.0258 - val_accuracy: 0.9926
# Epoch 7/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 0.0275 - val_accuracy: 0.9920
# Epoch 8/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0373 - val_accuracy: 0.9905
# Epoch 9/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.0413 - val_accuracy: 0.9919
# Epoch 10/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0507 - val_accuracy: 0.9903
# Epoch 11/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0436 - val_accuracy: 0.9913
# Epoch 12/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0426 - val_accuracy: 0.9921
# Epoch 13/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0507 - val_accuracy: 0.9903
# Epoch 14/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0407 - val_accuracy: 0.9916
# Epoch 15/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0462 - val_accuracy: 0.9921
# Epoch 16/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0528 - val_accuracy: 0.9916
# Epoch 17/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0517 - val_accuracy: 0.9927
# Epoch 18/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0633 - val_accuracy: 0.9915
# Epoch 19/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0519 - val_accuracy: 0.9927
# Epoch 20/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.0530 - val_accuracy: 0.9935
# Epoch 21/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0665 - val_accuracy: 0.9925
# Epoch 22/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0632 - val_accuracy: 0.9925
# Epoch 23/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0614 - val_accuracy: 0.9922
# Epoch 24/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0699 - val_accuracy: 0.9922
# Epoch 25/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0736 - val_accuracy: 0.9927
# Epoch 26/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0928 - val_accuracy: 0.9916
# Epoch 27/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0714 - val_accuracy: 0.9921
# Epoch 28/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0778 - val_accuracy: 0.9929
# Epoch 29/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0791 - val_accuracy: 0.9929
# Epoch 30/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0861 - val_accuracy: 0.9928

# %%
model = models.Sequential()

model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_data, train_labels ,
                    epochs=30, 
                    batch_size=64,
                    validation_data=(test_data, test_labels))

show_plot(history)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 16)        160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 64)          18496
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                36928
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 60,874
# Trainable params: 60,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2015 - accuracy: 0.9379 - val_loss: 0.0612 - val_accuracy: 0.9812
# Epoch 2/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0549 - accuracy: 0.9826 - val_loss: 0.0427 - val_accuracy: 0.9864
# Epoch 3/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0392 - accuracy: 0.9879 - val_loss: 0.0313 - val_accuracy: 0.9886
# Epoch 4/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0303 - accuracy: 0.9909 - val_loss: 0.0320 - val_accuracy: 0.9907
# Epoch 5/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0241 - accuracy: 0.9928 - val_loss: 0.0362 - val_accuracy: 0.9883
# Epoch 6/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.0298 - val_accuracy: 0.9911
# Epoch 7/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.0238 - val_accuracy: 0.9933
# Epoch 8/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0139 - accuracy: 0.9959 - val_loss: 0.0305 - val_accuracy: 0.9909
# Epoch 9/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0121 - accuracy: 0.9964 - val_loss: 0.0358 - val_accuracy: 0.9921
# Epoch 10/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0314 - val_accuracy: 0.9922
# Epoch 11/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0327 - val_accuracy: 0.9918
# Epoch 12/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0316 - val_accuracy: 0.9925
# Epoch 13/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0376 - val_accuracy: 0.9918
# Epoch 14/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0408 - val_accuracy: 0.9924
# Epoch 15/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0426 - val_accuracy: 0.9924
# Epoch 16/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0421 - val_accuracy: 0.9932
# Epoch 17/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0452 - val_accuracy: 0.9922
# Epoch 18/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0486 - val_accuracy: 0.9907
# Epoch 19/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0520 - val_accuracy: 0.9922
# Epoch 20/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0566 - val_accuracy: 0.9921
# Epoch 21/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0492 - val_accuracy: 0.9927
# Epoch 22/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0582 - val_accuracy: 0.9908
# Epoch 23/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0563 - val_accuracy: 0.9930
# Epoch 24/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0638 - val_accuracy: 0.9913
# Epoch 25/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0612 - val_accuracy: 0.9931
# Epoch 26/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0658 - val_accuracy: 0.9928
# Epoch 27/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0620 - val_accuracy: 0.9921
# Epoch 28/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0644 - val_accuracy: 0.9927
# Epoch 29/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0905 - val_accuracy: 0.9916
# Epoch 30/30
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0755 - val_accuracy: 0.9931

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))

show_plot(history)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                36928
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

optim = optimizers.Adam(learning_rate=0.1)

model.compile(optimizer=optim,
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# 0.0001 = 1e-4
optim = optimizers.Adam(learning_rate=1e-4)

model.compile(optimizer=optim,
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

#setting the optimizer
optim = optimizers.SGD(learning_rate=0.0001)

model.compile(optimizer=optim,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

#Setting the optimizer
optim = optimizers.SGD(learning_rate=0.0001, momentum=0.9)

model.compile(optimizer=optim,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

optim = optimizers.SGD(learning_rate=0.0001, momentum=0.8)

model.compile(optimizer=optim,
              loss='categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

optim = optimizers.SGD(learning_rate=0.0001, momentum=0.65)

model.compile(optimizer=optim,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

optim = optimizers.SGD(learning_rate=0.001, momentum=0.9)

model.compile(optimizer=optim,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)
print(max(history.history['val_accuracy']))
print(min(history.history['val_loss']))
# Out:
# 0.9890000224113464
# 0.034990254789590836

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

optim = optimizers.SGD(learning_rate=0.001, momentum=0.65)

model.compile(optimizer=optim,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#Testing with normalization data
history = model.fit(train_data, train_labels,
                    epochs=30,
                    batch_size=64,
                    verbose=0,
                    validation_data=(test_data, test_labels))


show_plot(history)
print(max(history.history['val_accuracy']))
print(min(history.history['val_loss']))
# Out:
# 0.9842000007629395
# 0.0519111193716526

# %%
from sklearn.neighbors import KNeighborsClassifier

accuracies = []

# loop over various values of `k` for the k-Nearest Neighbor classifier
for k in range(1,4,2):
	# train the k-Nearest Neighbor classifier with the current value of `k`
	model = KNeighborsClassifier(n_neighbors=k)
	model.fit(train_data, train_labels)

	# evaluate the model and update the accuracies list
	score = model.score(test_data, test_labels)
	print("k=%d, accuracy=%.2f%%" % (k, score * 100))
	accuracies.append(score)
# Out:
# k=1, accuracy=96.91%
# k=3, accuracy=97.05%

# %%
from sklearn.neighbors import NearestCentroid

model2 = NearestCentroid()
model2.fit(train_data, train_labels)

score = model2.score(test_data, test_labels)
print("Nearest Centroid, accuracy=%.2f%%" % (score * 100))
# Out:
# Nearest Centroid, accuracy=82.03%
