# %%
import numpy as np
from keras.datasets import mnist
from keras import layers
from keras import models
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

# %%
print(train_data.shape)
print(test_data.shape)

train_data = train_data.reshape((60000, 28 * 28))
train_data = train_data.astype('float32') / 255

test_data = test_data.reshape((10000, 28 * 28))
test_data = test_data.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'relu', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'relu', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=30, 
                      batch_size=128,
                      validation_data=(test_data,test_labels))

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/30
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2899 - accuracy: 0.9186 - val_loss: 0.1502 - val_accuracy: 0.9567
# Epoch 2/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1246 - accuracy: 0.9635 - val_loss: 0.0999 - val_accuracy: 0.9708
# Epoch 3/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0856 - accuracy: 0.9750 - val_loss: 0.0870 - val_accuracy: 0.9731
# Epoch 4/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0635 - accuracy: 0.9809 - val_loss: 0.0771 - val_accuracy: 0.9761
# Epoch 5/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0507 - accuracy: 0.9847 - val_loss: 0.0793 - val_accuracy: 0.9750
# Epoch 6/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0408 - accuracy: 0.9877 - val_loss: 0.0654 - val_accuracy: 0.9800
# Epoch 7/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0334 - accuracy: 0.9903 - val_loss: 0.0705 - val_accuracy: 0.9790
# Epoch 8/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0271 - accuracy: 0.9926 - val_loss: 0.0699 - val_accuracy: 0.9791
# Epoch 9/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0222 - accuracy: 0.9938 - val_loss: 0.0671 - val_accuracy: 0.9799
# Epoch 10/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0182 - accuracy: 0.9954 - val_loss: 0.0677 - val_accuracy: 0.9802
# Epoch 11/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0150 - accuracy: 0.9961 - val_loss: 0.0689 - val_accuracy: 0.9811
# Epoch 12/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.0757 - val_accuracy: 0.9799
# Epoch 13/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.0692 - val_accuracy: 0.9815
# Epoch 14/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 0.0718 - val_accuracy: 0.9815
# Epoch 15/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.0765 - val_accuracy: 0.9815
# Epoch 16/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.0761 - val_accuracy: 0.9807
# Epoch 17/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0821 - val_accuracy: 0.9794
# Epoch 18/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0862 - val_accuracy: 0.9802
# Epoch 19/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0831 - val_accuracy: 0.9816
# Epoch 20/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0841 - val_accuracy: 0.9819
# Epoch 21/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0912 - val_accuracy: 0.9804
# Epoch 22/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0989 - val_accuracy: 0.9797
# Epoch 23/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1018 - val_accuracy: 0.9801
# Epoch 24/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0944 - val_accuracy: 0.9808
# Epoch 25/30
# 469/469 [==============================] - 2s 3ms/step - loss: 7.7903e-04 - accuracy: 0.9998 - val_loss: 0.1014 - val_accuracy: 0.9806
# Epoch 26/30
# 469/469 [==============================] - 2s 3ms/step - loss: 7.3372e-04 - accuracy: 0.9998 - val_loss: 0.1090 - val_accuracy: 0.9798
# Epoch 27/30
# 469/469 [==============================] - 2s 3ms/step - loss: 5.0598e-04 - accuracy: 0.9999 - val_loss: 0.1109 - val_accuracy: 0.9813
# Epoch 28/30
# 469/469 [==============================] - 2s 3ms/step - loss: 4.6698e-04 - accuracy: 0.9999 - val_loss: 0.1069 - val_accuracy: 0.9817
# Epoch 29/30
# 469/469 [==============================] - 2s 3ms/step - loss: 4.5215e-04 - accuracy: 0.9998 - val_loss: 0.1087 - val_accuracy: 0.9808
# Epoch 30/30
# 469/469 [==============================] - 2s 3ms/step - loss: 4.0938e-04 - accuracy: 0.9999 - val_loss: 0.1138 - val_accuracy: 0.9808

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
history = network.fit(train_data, train_labels, 
                      epochs=10, 
                      batch_size=128,
                      validation_data=(test_data,test_labels))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 2s 3ms/step - loss: 2.1612e-04 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9808
# Epoch 2/10
# 469/469 [==============================] - 2s 3ms/step - loss: 2.1038e-04 - accuracy: 0.9999 - val_loss: 0.1160 - val_accuracy: 0.9809
# Epoch 3/10
# 469/469 [==============================] - 2s 3ms/step - loss: 1.5898e-04 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9810
# Epoch 4/10
# 469/469 [==============================] - 2s 3ms/step - loss: 1.4827e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9814
# Epoch 5/10
# 469/469 [==============================] - 2s 3ms/step - loss: 1.7690e-04 - accuracy: 0.9999 - val_loss: 0.1328 - val_accuracy: 0.9806
# Epoch 6/10
# 469/469 [==============================] - 2s 3ms/step - loss: 1.0589e-04 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9804
# Epoch 7/10
# 469/469 [==============================] - 2s 3ms/step - loss: 1.1110e-04 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9807
# Epoch 8/10
# 469/469 [==============================] - 2s 3ms/step - loss: 4.9418e-05 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9819
# Epoch 9/10
# 469/469 [==============================] - 2s 3ms/step - loss: 6.4303e-05 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9809
# Epoch 10/10
# 469/469 [==============================] - 2s 4ms/step - loss: 4.5211e-05 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9811

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'relu', input_shape=(28*28,)))
network.add(layers.Dense(128, activation = 'relu'))
network.add(layers.Dense(128, activation = 'relu'))
network.add(layers.Dense(128, activation = 'relu'))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=10, 
                      batch_size=128,
                      validation_data=(test_data,test_labels))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2819 - accuracy: 0.9140 - val_loss: 0.1305 - val_accuracy: 0.9600
# Epoch 2/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1086 - accuracy: 0.9670 - val_loss: 0.1108 - val_accuracy: 0.9652
# Epoch 3/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0723 - accuracy: 0.9776 - val_loss: 0.1120 - val_accuracy: 0.9671
# Epoch 4/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0557 - accuracy: 0.9829 - val_loss: 0.0848 - val_accuracy: 0.9758
# Epoch 5/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0443 - accuracy: 0.9865 - val_loss: 0.0767 - val_accuracy: 0.9794
# Epoch 6/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0358 - accuracy: 0.9894 - val_loss: 0.0792 - val_accuracy: 0.9779
# Epoch 7/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0283 - accuracy: 0.9915 - val_loss: 0.0926 - val_accuracy: 0.9787
# Epoch 8/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.0949 - val_accuracy: 0.9798
# Epoch 9/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0219 - accuracy: 0.9934 - val_loss: 0.1087 - val_accuracy: 0.9780
# Epoch 10/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.1133 - val_accuracy: 0.9809

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=30, 
                      batch_size=256,
                      verbose=0,
                      validation_data=(test_data,test_labels))

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(128, activation = 'sigmoid'))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=15, 
                      batch_size=128,
                      verbose=0,
                      validation_data=(test_data,test_labels))

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=15,
                      batch_size=128,
                      verbose=0,
                      validation_data=(test_data,test_labels))

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network = models.Sequential()
network.add(layers.Dense(256, activation = 'sigmoid', input_shape=(28*28,)))
network.add(layers.Dense(10, activation = 'softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_data, train_labels, 
                      epochs=60, 
                      batch_size=256,
                      verbose=0,
                      validation_data=(test_data,test_labels))

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print(val_acc[20])
# Out:
# 0.9779999852180481
